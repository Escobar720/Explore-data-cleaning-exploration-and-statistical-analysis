# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\sajee\Internship file folder\data analysis and visualization\full.csv")

# %%
df.shape
# Out:
# (1309, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
categorical = df.dtypes[df.dtypes == "object"].index
print(categorical)

df[categorical].describe()
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'Name_wiki', 'Hometown',
#        'Boarded', 'Destination', 'Lifeboat', 'Body'],
#       dtype='object')
#                         Name   Sex    Ticket        Cabin Embarked  \
# count                   1309  1309      1309          295     1307
# unique                  1307     2       929          186        3
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S
# freq                       2   843        11            6      914
#
#                Name_wiki                Hometown      Boarded    Destination  \
# count               1304                    1304         1304           1304
# unique              1303                     566            4            291
# top     Kelly, Mr. James  New York, New York, US  Southampton  New York City
# freq                   2                      70          916            234
#
#        Lifeboat   Body
# count       502    130
# unique       24    130
# ...

# %%
del df["PassengerId"]

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0       3                            Braund, Mr. Owen Harris
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0       3                             Heikkinen, Miss. Laina
# 3       1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    WikiId                                   Name_wiki  Age_wiki  \
# ...

# %%
sorted(df["Name"])[0:15]
# Out:
# ['Abbing, Mr. Anthony',
#  'Abbott, Master. Eugene Joseph',
#  'Abbott, Mr. Rossmore Edward',
#  'Abbott, Mrs. Stanton (Rosa Hunt)',
#  'Abelseth, Miss. Karen Marie',
#  'Abelseth, Mr. Olaus Jorgensen',
#  'Abelson, Mr. Samuel',
#  'Abelson, Mrs. Samuel (Hannah Wizosky)',
#  'Abrahamsson, Mr. Abraham August Johannes',
#  'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#  'Adahl, Mr. Mauritz Nils Martin',
#  'Adams, Mr. John',
#  'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Aks, Master. Philip Frank',
#  'Aks, Mrs. Sam (Leah Rosen)']

# %%
df["Name"].describe()
# Out:
# count                     1309
# unique                    1307
# top       Connolly, Miss. Kate
# freq                         2
# Name: Name, dtype: object

# %%
df["Ticket"][0:15]
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# Name: Ticket, dtype: object

# %%
df["Ticket"].describe()
# Out:
# count         1309
# unique         929
# top       CA. 2343
# freq            11
# Name: Ticket, dtype: object

# %%
del df["Ticket"]

# %%
df["Cabin"][0:15]
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3     C123
# 4      NaN
# 5      NaN
# 6      E46
# 7      NaN
# 8      NaN
# 9      NaN
# 10      G6
# 11    C103
# 12     NaN
# 13     NaN
# 14     NaN
# Name: Cabin, dtype: object

# %%
df["Cabin"].describe()
# Out:
# count             295
# unique            186
# top       C23 C25 C27
# freq                6
# Name: Cabin, dtype: object

# %% [markdown]
# # Should I Transform Any Variables?
#
# ## When you first load a data set, some of the variables may be encoded as data types that don't fit well with what the data really is or what it means.For instance, Survived is just an integer variable that takes on the value 0 or 1 depending on whether a passenger died or survived respectively. Variables that indicate a state or the presence or absence of something with the numbers 0 and 1 are sometimes called indicator variables or dummy variables (0 indicates absence and 1 indicates presence.). Indicator variables are essentially just a shorthand for encoding a categorical variable with 2 levels. We could instead encode Survived as a categorical variable with more descriptive categories:

# %%
new_survived = pd.Categorical(df['Survived'])
new_survived = new_survived.rename_categories(['Died' , 'Survived'])

new_survived.describe()
# Out:
#             counts     freqs
# categories
# Died           549  0.419404
# Survived       342  0.261268
# NaN            418  0.319328

# %%
new_Pclass = pd.Categorical(df['Pclass'])
new_Pclass = new_Pclass.rename_categories(['class 1' , 'class 2' , 'class 3'])

new_Pclass.describe()
# Out:
#             counts     freqs
# categories
# class 1        323  0.246753
# class 2        277  0.211612
# class 3        709  0.541635

# %%
df['Pclass'] = new_Pclass

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
char_cabin = df["Cabin"].astype(str) # Convert data to str

new_Cabin = np.array([cabin[0] for cabin in char_cabin]) # Take first letter

new_Cabin = pd.Categorical(new_Cabin)

new_Cabin .describe()
# Out:
#             counts     freqs
# categories
# A               22  0.016807
# B               65  0.049656
# C               94  0.071811
# D               46  0.035141
# E               41  0.031322
# F               21  0.016043
# G                5  0.003820
# T                1  0.000764
# n             1014  0.774637

# %%
df['Cabin'] = new_Cabin

# %%
df["Age"].describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
missing = np.where(df["Age"].isnull() == True)
missing
# Out:
# (array([   5,   17,   19,   26,   28,   29,   31,   32,   36,   42,   45,
#           46,   47,   48,   55,   64,   65,   76,   77,   82,   87,   95,
#          101,  107,  109,  121,  126,  128,  140,  154,  158,  159,  166,
#          168,  176,  180,  181,  185,  186,  196,  198,  201,  214,  223,
#          229,  235,  240,  241,  250,  256,  260,  264,  270,  274,  277,
#          284,  295,  298,  300,  301,  303,  304,  306,  324,  330,  334,
#          335,  347,  351,  354,  358,  359,  364,  367,  368,  375,  384,
#          388,  409,  410,  411,  413,  415,  420,  425,  428,  431,  444,
#          451,  454,  457,  459,  464,  466,  468,  470,  475,  481,  485,
#          490,  495,  497,  502,  507,  511,  517,  522,  524,  527,  531,
#          533,  538,  547,  552,  557,  560,  563,  564,  568,  573,  578,
#          584,  589,  593,  596,  598,  601,  602,  611,  612,  613,  629,
#          633,  639,  643,  648,  650,  653,  656,  667,  669,  674,  680,
# ...

# %%
len(missing[0])
# Out:
# 263

# %%
df.hist(column='Age',    # Column to plot
                   figsize=(9,6),   # Plot size
                   bins=20)         # Number of histogram bins
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
new_age_var = np.where(df["Age"].isnull(), # Logical check
                       28,                       # Value if check is true
                       df["Age"])     # Value if check is false

df["Age"] = new_age_var 

df["Age"].describe()
# Out:
# count    1309.000000
# mean       29.503186
# std        12.905241
# min         0.170000
# 25%        22.000000
# 50%        28.000000
# 75%        35.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
df.hist(column='Age',    # Column to plot
                   figsize=(9,6),   # Plot size
                   bins=20)         # Number of histogram bins
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
df["Fare"].plot(kind="box",
                           figsize=(9,9))
# Out:
# <Axes: >

# %%
index = np.where(df["Fare"] == max(df["Fare"]) )

df.loc[index]
# Out:
#       Survived   Pclass                                               Name  \
# 258        1.0  class 1                                   Ward, Miss. Anna
# 679        1.0  class 1                 Cardeza, Mr. Thomas Drake Martinez
# 737        1.0  class 1                             Lesurer, Mr. Gustave J
# 1234       NaN  class 1  Cardeza, Mrs. James Warburton Martinez (Charlo...
#
#          Sex   Age  SibSp  Parch      Fare Cabin Embarked  WikiId  \
# 258   female  35.0      0      0  512.3292     n        C    51.0
# 679     male  36.0      0      1  512.3292     B        C    52.0
# 737     male  35.0      0      0  512.3292     B        C    53.0
# 1234  female  58.0      0      1  512.3292     B        C    50.0
#
#                                        Name_wiki  Age_wiki  \
# 258              and maid, Miss Annie Moore Ward      38.0
# 679           Cardeza, Mr. Thomas Drake Martinez      36.0
# 737            and valet, Mr. Gustave J. Lesueur      35.0
# ...

# %%
df["Family"] = df["SibSp"] + df["Parch"]

# %%
most_family = np.where(df["Family"] == max(df["Family"]))

df.loc[most_family]
# Out:
#       Survived   Pclass                               Name     Sex   Age  \
# 159        0.0  class 3         Sage, Master. Thomas Henry    male  28.0
# 180        0.0  class 3       Sage, Miss. Constance Gladys  female  28.0
# 201        0.0  class 3                Sage, Mr. Frederick    male  28.0
# 324        0.0  class 3           Sage, Mr. George John Jr    male  28.0
# 792        0.0  class 3            Sage, Miss. Stella Anna  female  28.0
# 846        0.0  class 3           Sage, Mr. Douglas Bullen    male  28.0
# 863        0.0  class 3  Sage, Miss. Dorothy Edith "Dolly"  female  28.0
# 1079       NaN  class 3                    Sage, Miss. Ada  female  28.0
# 1233       NaN  class 3              Sage, Mr. John George    male  28.0
# 1251       NaN  class 3        Sage, Master. William Henry    male  14.5
# 1256       NaN  class 3     Sage, Mrs. John (Annie Bullen)  female  28.0
#
#       SibSp  Parch   Fare Cabin Embarked  WikiId  \
# ...

# %% [markdown]
# ## Wrap Up
# # In this lesson, we covered several general questions you should address when you first inspect a data set. Your first goal should be to explore the structure of the data to clean it and prepare the variables for your analysis. Once your data is it the right form, you can move from exploring structure to investigating relationships between variables. Since data cleaning and formatting is a vital and often time-consuming part of data analysis, it is important that we spend some time learning how to work with different types of data. Over the next few lessons, we'll learn about cleaning and preprocessing text data, numeric data and dates.
